# %%
import os,sys
get_ipython().run_line_magic('matplotlib','inline')
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
import tensorflow as tf
import numpy as np
np.random.seed(1)
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import time
from collections import Counter
hdir = '/home/selab/Desktop/SELab_sy/NMSC/NMSC_2018/'
wdir = '/home/selab/Desktop/SELab_sy/NMSC/RNN/lstm_ch31/'
# Out:
# /home/selab/anaconda3/envs/tensorflow/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/selab/anaconda3/envs/tensorflow/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def nearest(items,pivot):
    temp = min(items, key=lambda x: abs(x - pivot))
    return items.index(temp)

# %%
#kp to idx
kp2idx = {0.0:0, 0.3:1, 0.7:2, 1.0:3, 1.3:4, 1.7:5, 2.0:6, 2.3:7, 2.7:8, 3.0:9, 3.3:10, 3.7:11, 4.0:12, 4.3:13,
           4.7:14, 5.0:15, 5.3:16, 5.7:17, 6.0:18, 6.3:19, 6.7:20, 7.0:21, 7.3:22, 7.7:23, 8.0:24, 8.3:25, 8.7:26, 9.0:27}
#idx to kp
idx2kp = {0:0.0, 1:0.3, 2:0.7, 3:1.0, 4:1.3, 5:1.7, 6:2.0, 7:2.3, 8:2.7, 9:3.0, 10:3.3, 11:3.7, 12:4.0, 13:4.3,
           14:4.7, 15:5.0, 16:5.3, 17:5.7, 18:6.0, 19:6.3, 20:6.7, 21:7.0, 22:7.3, 23:7.7, 24:8.0, 25:8.3, 26:8.7, 27:9.0}    

max_idx_value = 27

# %%
#Kp index
data_kp = np.genfromtxt(hdir + 'KP_total.txt', names="year, month, day, hour, kp", dtype=(int, int, int, float,float))

# %%
#kp index daily number check
#total 6574 days, each 8 values
kp_time = []
for i in range(len(data_kp["kp"])):
    kp_time.append(datetime.datetime(data_kp["year"][i],data_kp["month"][i],data_kp["day"][i],int(data_kp["hour"][i]),30))

kp_date = []
for i in range(len(data_kp["kp"])):
    kp_date.append(datetime.date(data_kp["year"][i],data_kp["month"][i],data_kp["day"][i]))

tdel = kp_date[-1]-kp_date[0]

# %%
#max kp extraction
#kp2idx 
kp_max = []
kp_max_date = []
kp_timeHist = []
for i in range(tdel.days + 1):
    j=8*i
    maxidx = np.argmax(data_kp["kp"][j:j+8])
    kp_max.append(kp2idx[data_kp["kp"][j+maxidx]])
    kp_max_date.append(kp_date[j+maxidx])
    temp = kp_time[j+maxidx].time()
    kp_timeHist.append(temp.hour)

# %%
#CH
data_ch_reg = np.genfromtxt(hdir + 'CH_Regions_025scl2.dat', dtype=[('date', '<i8'), ('loc', '<U136')])

# %%
ch_time = []
ch_date = []
for i in range(len(data_ch_reg)):
    stamp = data_ch_reg["date"][i]
    ch_time.append(datetime.datetime(int(str(stamp)[0:4]),int(str(stamp)[4:6]),int(str(stamp)[6:8]),int(str(stamp)[8:10]),int(str(stamp)[10:12])))
    ch_date.append(datetime.date(int(str(stamp)[0:4]),int(str(stamp)[4:6]),int(str(stamp)[6:8])))

ch_date = list(set(ch_date))
ch_date.sort()

# %%
ch_reg = []

for i in range(len(ch_date)):
    nindx = nearest(ch_time,datetime.datetime.combine(ch_date[i],datetime.datetime.min.time()))
    ch_reg.append([data_ch_reg[nindx][0]]+[int(n) for n in data_ch_reg[nindx][1]])

# %%
#same observation data for kp and ch
#dat_tot에는 예측 기준날짜,지난 3일치 CH 데이터(136크기 어레이 *3), 예측할 kp값 이렇게 들어있음
dat_tot = []
for i in range(3,len(ch_date)):
    idx = kp_max_date.index(ch_date[i])
    dat_tot.append([ch_date[i],ch_reg[i-3][1:],ch_reg[i-2][1:],ch_reg[i-1][1:],kp_max[idx]])

# %%
## train, valid, test data set ##
div_tr = 6
div_va = 3
div_te = 3
div = int(len(dat_tot)/10*div_tr)

train = dat_tot[:int(div)]
val = dat_tot[int(div):int(div/div_tr*(div_tr+div_va))]
test = dat_tot[int(div/div_tr*(div_tr+div_va)):int(div/div_tr*(div_tr+div_va+div_te))]
print(len(train),len(val),len(test))
# Out:
# 2578 1289 430

# %%
#CH의 경우 입력값 정규화 하지 않음. [1,0]이기 때문
x_train = np.array([xi[1:4] for xi in train])
y_train = np.array([yi[4] for yi in train]) #라벨 정규화는 필요없음
y_train = tf.keras.utils.to_categorical(y_train,28)

x_val =  np.array([xi[1:4] for xi in val])
y_val = np.array([yi[4] for yi in val])
y_val = tf.keras.utils.to_categorical(y_val,28)

# %%
x_te = np.array([xi[1:4] for xi in test])
y_te = np.array([yi[4] for yi in test])
y_te = tf.keras.utils.to_categorical(y_te,28)

# %%
# 3ch input 1 kp output
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(40, batch_input_shape = (1,3,136), stateful=False, return_sequences=True))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.LSTM(20, input_shape = (1,3,136),stateful=False))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(28,activation='softmax'))
#Dense(1)으로 해서 값을 바로 넣으면?

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (1, 3, 40)                28320
# _________________________________________________________________
# dropout_8 (Dropout)          (1, 3, 40)                0
# _________________________________________________________________
# lstm_17 (LSTM)               (1, 20)                   4880
# _________________________________________________________________
# dropout_9 (Dropout)          (1, 20)                   0
# _________________________________________________________________
# dense (Dense)                (1, 28)                   588
# =================================================================
# Total params: 33,788
# Trainable params: 33,788
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy','mse'])

# %%
#Callback ft
class CustomHistory(tf.keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        self.train_acc = []
        self.val_acc = []        
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))
        self.train_acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))

# %%
#Early stopper
def EarlyStop(history,patience):
    if len(history.val_loss)<=1 : 
        print('hislength')
        return patience
    
    nowloss = history.val_loss[-1]
    lastloss = history.val_loss[-2]
    if nowloss > lastloss :
        patience -= 1
    
    print('patience = '+str(patience))
    print('----------------------')
    return patience

# %%
num_epochs = 100
pat = 1
custom_hist = CustomHistory()
custom_hist.init()

# %%
#no early stopper
model.fit(x_train,y_train,epochs=num_epochs,batch_size=1, verbose=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val,y_val))
# Out:
# Train on 2578 samples, validate on 1289 samples
# Epoch 1/100
# 2578/2578 [==============================] - 44s 17ms/step - loss: 2.9256 - acc: 0.0962 - mean_squared_error: 0.0335 - val_loss: 2.9373 - val_acc: 0.0776 - val_mean_squared_error: 0.0336
# Epoch 2/100
# 2578/2578 [==============================] - 40s 16ms/step - loss: 2.8272 - acc: 0.1121 - mean_squared_error: 0.0332 - val_loss: 2.9700 - val_acc: 0.0846 - val_mean_squared_error: 0.0337
# Epoch 3/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 2.7918 - acc: 0.1137 - mean_squared_error: 0.0330 - val_loss: 2.9702 - val_acc: 0.0807 - val_mean_squared_error: 0.0336
# Epoch 4/100
# 2578/2578 [==============================] - 46s 18ms/step - loss: 2.7540 - acc: 0.1191 - mean_squared_error: 0.0329 - val_loss: 3.0040 - val_acc: 0.0745 - val_mean_squared_error: 0.0338
# Epoch 5/100
# 2578/2578 [==============================] - 48s 18ms/step - loss: 2.7235 - acc: 0.1311 - mean_squared_error: 0.0328 - val_loss: 3.0529 - val_acc: 0.0737 - val_mean_squared_error: 0.0339
# Epoch 6/100
# 2578/2578 [==============================] - 47s 18ms/step - loss: 2.6813 - acc: 0.1373 - mean_squared_error: 0.0326 - val_loss: 3.0477 - val_acc: 0.0815 - val_mean_squared_error: 0.0339
# Epoch 7/100
# 2578/2578 [==============================] - 48s 19ms/step - loss: 2.6380 - acc: 0.1524 - mean_squared_error: 0.0324 - val_loss: 3.0484 - val_acc: 0.0853 - val_mean_squared_error: 0.0339
# Epoch 8/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 2.5806 - acc: 0.1672 - mean_squared_error: 0.0321 - val_loss: 3.1549 - val_acc: 0.0776 - val_mean_squared_error: 0.0342
# Epoch 9/100
# 2578/2578 [==============================] - 46s 18ms/step - loss: 2.5356 - acc: 0.1893 - mean_squared_error: 0.0319 - val_loss: 3.2188 - val_acc: 0.0807 - val_mean_squared_error: 0.0344
# Epoch 10/100
# 2578/2578 [==============================] - 48s 18ms/step - loss: 2.4750 - acc: 0.2021 - mean_squared_error: 0.0316 - val_loss: 3.2123 - val_acc: 0.0877 - val_mean_squared_error: 0.0344
# Epoch 11/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 2.4230 - acc: 0.2083 - mean_squared_error: 0.0313 - val_loss: 3.2546 - val_acc: 0.0807 - val_mean_squared_error: 0.0346
# Epoch 12/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 2.3773 - acc: 0.2230 - mean_squared_error: 0.0310 - val_loss: 3.3036 - val_acc: 0.0838 - val_mean_squared_error: 0.0348
# Epoch 13/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 2.3048 - acc: 0.2378 - mean_squared_error: 0.0305 - val_loss: 3.3222 - val_acc: 0.0838 - val_mean_squared_error: 0.0349
# Epoch 14/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 2.2509 - acc: 0.2669 - mean_squared_error: 0.0301 - val_loss: 3.4957 - val_acc: 0.0791 - val_mean_squared_error: 0.0356
# Epoch 15/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 2.1819 - acc: 0.2917 - mean_squared_error: 0.0296 - val_loss: 3.5440 - val_acc: 0.0954 - val_mean_squared_error: 0.0356
# Epoch 16/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 2.1209 - acc: 0.3068 - mean_squared_error: 0.0292 - val_loss: 3.6709 - val_acc: 0.0830 - val_mean_squared_error: 0.0362
# Epoch 17/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 2.0814 - acc: 0.3185 - mean_squared_error: 0.0287 - val_loss: 3.6037 - val_acc: 0.0915 - val_mean_squared_error: 0.0362
# Epoch 18/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 2.0119 - acc: 0.3328 - mean_squared_error: 0.0281 - val_loss: 3.7960 - val_acc: 0.0737 - val_mean_squared_error: 0.0368
# Epoch 19/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.9659 - acc: 0.3448 - mean_squared_error: 0.0277 - val_loss: 3.8861 - val_acc: 0.0784 - val_mean_squared_error: 0.0371
# Epoch 20/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.9277 - acc: 0.3584 - mean_squared_error: 0.0273 - val_loss: 3.8630 - val_acc: 0.0869 - val_mean_squared_error: 0.0373
# Epoch 21/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.8633 - acc: 0.3871 - mean_squared_error: 0.0266 - val_loss: 3.9753 - val_acc: 0.0721 - val_mean_squared_error: 0.0377
# Epoch 22/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.8101 - acc: 0.4034 - mean_squared_error: 0.0260 - val_loss: 4.1118 - val_acc: 0.0776 - val_mean_squared_error: 0.0385
# Epoch 23/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.7662 - acc: 0.4216 - mean_squared_error: 0.0255 - val_loss: 4.0923 - val_acc: 0.0869 - val_mean_squared_error: 0.0381
# Epoch 24/100
# 2578/2578 [==============================] - 50s 20ms/step - loss: 1.7185 - acc: 0.4399 - mean_squared_error: 0.0251 - val_loss: 4.1165 - val_acc: 0.0776 - val_mean_squared_error: 0.0387
# Epoch 25/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.6808 - acc: 0.4395 - mean_squared_error: 0.0248 - val_loss: 4.1807 - val_acc: 0.0667 - val_mean_squared_error: 0.0392
# Epoch 26/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.6367 - acc: 0.4670 - mean_squared_error: 0.0240 - val_loss: 4.3253 - val_acc: 0.0799 - val_mean_squared_error: 0.0396
# Epoch 27/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.5943 - acc: 0.4794 - mean_squared_error: 0.0235 - val_loss: 4.3320 - val_acc: 0.0861 - val_mean_squared_error: 0.0396
# Epoch 28/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.5302 - acc: 0.5023 - mean_squared_error: 0.0227 - val_loss: 4.5014 - val_acc: 0.0737 - val_mean_squared_error: 0.0405
# Epoch 29/100
# 2578/2578 [==============================] - 50s 20ms/step - loss: 1.5047 - acc: 0.5043 - mean_squared_error: 0.0225 - val_loss: 4.5685 - val_acc: 0.0721 - val_mean_squared_error: 0.0409
# Epoch 30/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.4763 - acc: 0.5175 - mean_squared_error: 0.0220 - val_loss: 4.6553 - val_acc: 0.0737 - val_mean_squared_error: 0.0413
# Epoch 31/100
# 2578/2578 [==============================] - 52s 20ms/step - loss: 1.4368 - acc: 0.5365 - mean_squared_error: 0.0217 - val_loss: 4.8046 - val_acc: 0.0698 - val_mean_squared_error: 0.0415
# Epoch 32/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.4241 - acc: 0.5283 - mean_squared_error: 0.0215 - val_loss: 4.7600 - val_acc: 0.0807 - val_mean_squared_error: 0.0414
# Epoch 33/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.3755 - acc: 0.5462 - mean_squared_error: 0.0207 - val_loss: 5.0530 - val_acc: 0.0652 - val_mean_squared_error: 0.0421
# Epoch 34/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.3814 - acc: 0.5415 - mean_squared_error: 0.0209 - val_loss: 5.0747 - val_acc: 0.0613 - val_mean_squared_error: 0.0428
# Epoch 35/100
# 2578/2578 [==============================] - 51s 20ms/step - loss: 1.3195 - acc: 0.5815 - mean_squared_error: 0.0200 - val_loss: 5.0336 - val_acc: 0.0659 - val_mean_squared_error: 0.0430
# Epoch 36/100
# 2578/2578 [==============================] - 48s 19ms/step - loss: 1.2864 - acc: 0.5784 - mean_squared_error: 0.0198 - val_loss: 5.0947 - val_acc: 0.0628 - val_mean_squared_error: 0.0435
# Epoch 37/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 1.2753 - acc: 0.5737 - mean_squared_error: 0.0196 - val_loss: 5.2629 - val_acc: 0.0652 - val_mean_squared_error: 0.0437
# Epoch 38/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 1.2328 - acc: 0.6028 - mean_squared_error: 0.0189 - val_loss: 5.3007 - val_acc: 0.0636 - val_mean_squared_error: 0.0440
# Epoch 39/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.2017 - acc: 0.6036 - mean_squared_error: 0.0185 - val_loss: 5.4488 - val_acc: 0.0737 - val_mean_squared_error: 0.0441
# Epoch 40/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.1798 - acc: 0.6121 - mean_squared_error: 0.0182 - val_loss: 5.5078 - val_acc: 0.0690 - val_mean_squared_error: 0.0446
# Epoch 41/100
# 2578/2578 [==============================] - 50s 19ms/step - loss: 1.1500 - acc: 0.6237 - mean_squared_error: 0.0179 - val_loss: 5.5712 - val_acc: 0.0605 - val_mean_squared_error: 0.0448
# Epoch 42/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 1.1157 - acc: 0.6346 - mean_squared_error: 0.0174 - val_loss: 5.6422 - val_acc: 0.0605 - val_mean_squared_error: 0.0451
# Epoch 43/100
# 2578/2578 [==============================] - 40s 16ms/step - loss: 1.1158 - acc: 0.6362 - mean_squared_error: 0.0172 - val_loss: 5.5667 - val_acc: 0.0690 - val_mean_squared_error: 0.0447
# Epoch 44/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 1.0763 - acc: 0.6505 - mean_squared_error: 0.0167 - val_loss: 5.5653 - val_acc: 0.0683 - val_mean_squared_error: 0.0452
# Epoch 45/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 1.0400 - acc: 0.6610 - mean_squared_error: 0.0163 - val_loss: 5.8703 - val_acc: 0.0566 - val_mean_squared_error: 0.0461
# Epoch 46/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 1.0611 - acc: 0.6590 - mean_squared_error: 0.0165 - val_loss: 5.9826 - val_acc: 0.0683 - val_mean_squared_error: 0.0465
# Epoch 47/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 1.0426 - acc: 0.6583 - mean_squared_error: 0.0165 - val_loss: 5.8853 - val_acc: 0.0690 - val_mean_squared_error: 0.0461
# Epoch 48/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 1.0374 - acc: 0.6540 - mean_squared_error: 0.0164 - val_loss: 5.9908 - val_acc: 0.0652 - val_mean_squared_error: 0.0468
# Epoch 49/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.9846 - acc: 0.6753 - mean_squared_error: 0.0156 - val_loss: 6.1753 - val_acc: 0.0605 - val_mean_squared_error: 0.0470
# Epoch 50/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.9847 - acc: 0.6687 - mean_squared_error: 0.0157 - val_loss: 5.9804 - val_acc: 0.0559 - val_mean_squared_error: 0.0466
# Epoch 51/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.9421 - acc: 0.6951 - mean_squared_error: 0.0150 - val_loss: 6.1245 - val_acc: 0.0652 - val_mean_squared_error: 0.0472
# Epoch 52/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.9099 - acc: 0.7087 - mean_squared_error: 0.0144 - val_loss: 6.4049 - val_acc: 0.0551 - val_mean_squared_error: 0.0479
# Epoch 53/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8919 - acc: 0.7040 - mean_squared_error: 0.0143 - val_loss: 6.2265 - val_acc: 0.0590 - val_mean_squared_error: 0.0477
# Epoch 54/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.9314 - acc: 0.6963 - mean_squared_error: 0.0149 - val_loss: 6.3636 - val_acc: 0.0652 - val_mean_squared_error: 0.0478
# Epoch 55/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8735 - acc: 0.7188 - mean_squared_error: 0.0140 - val_loss: 6.3446 - val_acc: 0.0636 - val_mean_squared_error: 0.0477
# Epoch 56/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8628 - acc: 0.7095 - mean_squared_error: 0.0139 - val_loss: 6.3963 - val_acc: 0.0636 - val_mean_squared_error: 0.0478
# Epoch 57/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8576 - acc: 0.7211 - mean_squared_error: 0.0136 - val_loss: 6.5355 - val_acc: 0.0621 - val_mean_squared_error: 0.0486
# Epoch 58/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8535 - acc: 0.7211 - mean_squared_error: 0.0137 - val_loss: 6.7772 - val_acc: 0.0520 - val_mean_squared_error: 0.0492
# Epoch 59/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8314 - acc: 0.7188 - mean_squared_error: 0.0137 - val_loss: 6.8461 - val_acc: 0.0566 - val_mean_squared_error: 0.0492
# Epoch 60/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8160 - acc: 0.7347 - mean_squared_error: 0.0132 - val_loss: 6.6250 - val_acc: 0.0636 - val_mean_squared_error: 0.0491
# Epoch 61/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.8190 - acc: 0.7277 - mean_squared_error: 0.0133 - val_loss: 6.7295 - val_acc: 0.0535 - val_mean_squared_error: 0.0492
# Epoch 62/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7723 - acc: 0.7455 - mean_squared_error: 0.0126 - val_loss: 6.7265 - val_acc: 0.0559 - val_mean_squared_error: 0.0495
# Epoch 63/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7751 - acc: 0.7405 - mean_squared_error: 0.0127 - val_loss: 6.8727 - val_acc: 0.0504 - val_mean_squared_error: 0.0497
# Epoch 64/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7555 - acc: 0.7533 - mean_squared_error: 0.0122 - val_loss: 6.8790 - val_acc: 0.0520 - val_mean_squared_error: 0.0491
# Epoch 65/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7496 - acc: 0.7568 - mean_squared_error: 0.0123 - val_loss: 6.9718 - val_acc: 0.0512 - val_mean_squared_error: 0.0496
# Epoch 66/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7241 - acc: 0.7618 - mean_squared_error: 0.0118 - val_loss: 6.9418 - val_acc: 0.0590 - val_mean_squared_error: 0.0500
# Epoch 67/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7343 - acc: 0.7576 - mean_squared_error: 0.0120 - val_loss: 7.0230 - val_acc: 0.0605 - val_mean_squared_error: 0.0497
# Epoch 68/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7195 - acc: 0.7618 - mean_squared_error: 0.0118 - val_loss: 7.0798 - val_acc: 0.0675 - val_mean_squared_error: 0.0502
# Epoch 69/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7320 - acc: 0.7556 - mean_squared_error: 0.0122 - val_loss: 7.1636 - val_acc: 0.0574 - val_mean_squared_error: 0.0504
# Epoch 70/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.7020 - acc: 0.7719 - mean_squared_error: 0.0114 - val_loss: 7.0826 - val_acc: 0.0566 - val_mean_squared_error: 0.0505
# Epoch 71/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.6957 - acc: 0.7777 - mean_squared_error: 0.0113 - val_loss: 7.2115 - val_acc: 0.0597 - val_mean_squared_error: 0.0499
# Epoch 72/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.6720 - acc: 0.7882 - mean_squared_error: 0.0109 - val_loss: 7.2716 - val_acc: 0.0528 - val_mean_squared_error: 0.0505
# Epoch 73/100
# 2578/2578 [==============================] - 44s 17ms/step - loss: 0.6899 - acc: 0.7770 - mean_squared_error: 0.0112 - val_loss: 7.3047 - val_acc: 0.0605 - val_mean_squared_error: 0.0506
# Epoch 74/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.6529 - acc: 0.7925 - mean_squared_error: 0.0107 - val_loss: 7.3078 - val_acc: 0.0559 - val_mean_squared_error: 0.0507
# Epoch 75/100
# 2578/2578 [==============================] - 49s 19ms/step - loss: 0.6552 - acc: 0.7836 - mean_squared_error: 0.0107 - val_loss: 7.2922 - val_acc: 0.0574 - val_mean_squared_error: 0.0504
# Epoch 76/100
# 2578/2578 [==============================] - 53s 21ms/step - loss: 0.6390 - acc: 0.7843 - mean_squared_error: 0.0105 - val_loss: 7.3947 - val_acc: 0.0597 - val_mean_squared_error: 0.0513
# Epoch 77/100
# 2578/2578 [==============================] - 53s 20ms/step - loss: 0.6486 - acc: 0.7870 - mean_squared_error: 0.0106 - val_loss: 7.2241 - val_acc: 0.0628 - val_mean_squared_error: 0.0506
# Epoch 78/100
# 2578/2578 [==============================] - 52s 20ms/step - loss: 0.6222 - acc: 0.7944 - mean_squared_error: 0.0104 - val_loss: 7.3972 - val_acc: 0.0690 - val_mean_squared_error: 0.0509
# Epoch 79/100
# 2578/2578 [==============================] - 53s 21ms/step - loss: 0.6587 - acc: 0.7863 - mean_squared_error: 0.0107 - val_loss: 7.5042 - val_acc: 0.0621 - val_mean_squared_error: 0.0514
# Epoch 80/100
# 2578/2578 [==============================] - 53s 21ms/step - loss: 0.6006 - acc: 0.8029 - mean_squared_error: 0.0099 - val_loss: 7.6137 - val_acc: 0.0613 - val_mean_squared_error: 0.0514
# Epoch 81/100
# 2578/2578 [==============================] - 53s 20ms/step - loss: 0.5914 - acc: 0.8022 - mean_squared_error: 0.0098 - val_loss: 7.6144 - val_acc: 0.0652 - val_mean_squared_error: 0.0516
# Epoch 82/100
# 2578/2578 [==============================] - 52s 20ms/step - loss: 0.5891 - acc: 0.8057 - mean_squared_error: 0.0098 - val_loss: 7.8040 - val_acc: 0.0543 - val_mean_squared_error: 0.0522
# Epoch 83/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5979 - acc: 0.8053 - mean_squared_error: 0.0097 - val_loss: 7.6815 - val_acc: 0.0551 - val_mean_squared_error: 0.0519
# Epoch 84/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5836 - acc: 0.8123 - mean_squared_error: 0.0096 - val_loss: 7.5714 - val_acc: 0.0659 - val_mean_squared_error: 0.0513
# Epoch 85/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5629 - acc: 0.8177 - mean_squared_error: 0.0093 - val_loss: 7.6995 - val_acc: 0.0644 - val_mean_squared_error: 0.0518
# Epoch 86/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5544 - acc: 0.8169 - mean_squared_error: 0.0092 - val_loss: 7.6371 - val_acc: 0.0613 - val_mean_squared_error: 0.0517
# Epoch 87/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5834 - acc: 0.8196 - mean_squared_error: 0.0095 - val_loss: 7.5678 - val_acc: 0.0621 - val_mean_squared_error: 0.0517
# Epoch 88/100
# 2578/2578 [==============================] - 40s 16ms/step - loss: 0.5127 - acc: 0.8348 - mean_squared_error: 0.0085 - val_loss: 7.6811 - val_acc: 0.0690 - val_mean_squared_error: 0.0514
# Epoch 89/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.5413 - acc: 0.8126 - mean_squared_error: 0.0092 - val_loss: 7.9576 - val_acc: 0.0652 - val_mean_squared_error: 0.0527
# Epoch 90/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5755 - acc: 0.8053 - mean_squared_error: 0.0098 - val_loss: 7.9326 - val_acc: 0.0574 - val_mean_squared_error: 0.0529
# Epoch 91/100
# 2578/2578 [==============================] - 41s 16ms/step - loss: 0.5257 - acc: 0.8313 - mean_squared_error: 0.0089 - val_loss: 7.7224 - val_acc: 0.0628 - val_mean_squared_error: 0.0517
# Epoch 92/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.5321 - acc: 0.8289 - mean_squared_error: 0.0089 - val_loss: 7.6604 - val_acc: 0.0590 - val_mean_squared_error: 0.0517
# Epoch 93/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.5342 - acc: 0.8297 - mean_squared_error: 0.0089 - val_loss: 8.0304 - val_acc: 0.0659 - val_mean_squared_error: 0.0525
# Epoch 94/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.5262 - acc: 0.8258 - mean_squared_error: 0.0087 - val_loss: 7.8490 - val_acc: 0.0652 - val_mean_squared_error: 0.0519
# Epoch 95/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.5005 - acc: 0.8278 - mean_squared_error: 0.0084 - val_loss: 7.9821 - val_acc: 0.0605 - val_mean_squared_error: 0.0525
# Epoch 96/100
# 2578/2578 [==============================] - 43s 16ms/step - loss: 0.5298 - acc: 0.8227 - mean_squared_error: 0.0088 - val_loss: 7.8639 - val_acc: 0.0636 - val_mean_squared_error: 0.0525
# Epoch 97/100
# 2578/2578 [==============================] - 43s 16ms/step - loss: 0.5091 - acc: 0.8274 - mean_squared_error: 0.0085 - val_loss: 8.0051 - val_acc: 0.0636 - val_mean_squared_error: 0.0524
# Epoch 98/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.4855 - acc: 0.8441 - mean_squared_error: 0.0081 - val_loss: 8.0794 - val_acc: 0.0566 - val_mean_squared_error: 0.0527
# Epoch 99/100
# 2578/2578 [==============================] - 43s 17ms/step - loss: 0.5357 - acc: 0.8266 - mean_squared_error: 0.0088 - val_loss: 7.9037 - val_acc: 0.0574 - val_mean_squared_error: 0.0525
# Epoch 100/100
# 2578/2578 [==============================] - 42s 16ms/step - loss: 0.5016 - acc: 0.8313 - mean_squared_error: 0.0083 - val_loss: 8.1162 - val_acc: 0.0582 - val_mean_squared_error: 0.0532

# %% [raw]
# #No early stopper & prediction process image
# #temp1 = [ np.where(r==1)[0][0] for r in y_te[:100]]
# #temp2 = x_te[0:100]
# for epoch_idx in range(90):
#
#     print('epochs : ' + str(epoch_idx))
#     model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val,y_val))
#     model.reset_states()
#
#     #test evaluate & predict
#     scores = model.evaluate(x_te,y_te,batch_size=1)
#     print("Evaluate")
#     print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
#
#     yhat = model.predict_classes(x_te,batch_size=1)
#     temp = [np.where(y == 1)[0][0] for y in y_te]
#     count = 0
#     for i in range(len(temp)):
#         if temp[i] == yhat[i]: count +=1
#     print("Predict")
#     print("acc : %.2f%%" %(count/len(temp)*100))
#
#
#     plt.figure(figsize=(80,6))
#     plt.plot(temp,'-')
#     plt.plot(yhat,'-',alpha=1)
#     plt.savefig(wdir+'test_predict_%i.png'%(epoch_idx),dip=300)
#     plt.close()
#     plt.clf()
#
#
#     #train evaluate & predict
#     scores = model.evaluate(x_train,y_train,batch_size=1)
#     print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
#
#     yhat_tr = model.predict_classes(x_train,batch_size=1)
#     temp2 = [np.where(y == 1)[0][0] for y in y_train]
#     count = 0
#     for i in range(len(temp2)):
#         if temp2[i] == yhat_tr[i]: count +=1
#     print("predict")
#     print("acc : %.2f%%" %(count/len(temp2)*100))
#
#     plt.figure(figsize=(240,6))
#     plt.plot(temp2,'-')
#     plt.plot(yhat_tr,'-',alpha=1)
#     plt.savefig(wdir+'train_predict_%i.png'%(epoch_idx),dip=300)
#     plt.close()
#     plt.clf()

# %% [raw]
# #with early stopper & prediction process image
# temp1 = [ np.where(r==1)[0][0] for r in y_te[:100]]
# temp2 = x_te[0:100]
# for epoch_idx in range(num_epochs):
#
#     print('epochs : ' + str(epoch_idx))
#     model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val,y_val))
#     model.reset_states()
#
#     temp = model.predict_classes(temp2, batch_size = 1)
#
#     plt.figure(figsize=(18,6))
#     plt.xlabel('Index',fontsize=12)
#     plt.ylabel('Kp Label',fontsize=12)
#     plt.title('epochs_'+str(epoch_idx),fontsize=15)
#     plt.plot(temp1)
#     plt.plot(temp)
#     plt.savefig('epochs_'+str(epoch_idx)+'.png')
#     plt.close()
#
#     pat = EarlyStop(custom_hist,patience=pat)
#     if pat <= 0:
#         print('Early stopped')
#         break

# %%
model.save(wdir+'ch31.h5')

# %%
# %matplotlib inline

loss_ax = plt.subplot()

acc_ax = loss_ax.twinx()

loss_ax.plot(custom_hist.train_loss, 'y', label='train loss')
loss_ax.plot(custom_hist.val_loss, 'r', label='val loss')

acc_ax.plot(custom_hist.train_acc, 'b', label='train acc')
acc_ax.plot(custom_hist.val_acc, 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.savefig(wdir+'ch31.png')
plt.show()
plt.close()

# %%
#test evaluate & predict
scores = model.evaluate(x_te,y_te,batch_size=1)
print("Evaluate")
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

yhat = model.predict_classes(x_te,batch_size=1)
temp = [np.where(y == 1)[0][0] for y in y_te]
count = 0
for i in range(len(temp)):
    if temp[i] == yhat[i]: count +=1
print("Predict")
print("acc : %.2f%%" %(count/len(temp)*100))


plt.figure(figsize=(80,6))
plt.plot(temp,'-')
plt.plot(yhat,'-',alpha=1)
plt.savefig(wdir+'test_predict.png',dip=300)


#corr, SS
#제대로된 상관관계

y_te_la = np.asarray(temp)
sigref = np.std(y_te_la)
avgref = np.mean(y_te_la)

sigpre = np.std(yhat)
avgpre = np.mean(yhat)

corr = np.sum((y_te_la - avgref)*(yhat-avgpre))/sigref/sigpre/float(len(y_te_la))
print(corr)

#예측 효율 
mse_target = np.sum((y_te_la-yhat)**2)/len(y_te_la)
mse_ref = np.sum((y_te_la-avgref)**2)/len(yhat)
SS = 1-mse_target/mse_ref
print(SS)
# Out:
# 430/430 [==============================] - 1s 2ms/step
# Evaluate
# acc: 7.21%
# Predict
# acc : 7.21%
# 0.018105992745659757
# -1.1137705456228537

# %%
#train evaluate & predict 
scores = model.evaluate(x_train,y_train,batch_size=1)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

yhat_tr = model.predict_classes(x_train,batch_size=1)
temp2 = [np.where(y == 1)[0][0] for y in y_train]
count = 0
for i in range(len(temp2)):
    if temp2[i] == yhat_tr[i]: count +=1
print("predict")
print("acc : %.2f%%" %(count/len(temp2)*100))

plt.figure(figsize=(240,6))
plt.plot(temp2,'-')
plt.plot(yhat_tr,'-',alpha=1)
plt.savefig(wdir+'train_predict.png',dip=300)

#corr, SS
#제대로된 상관관계

y_te_la = np.asarray(temp2)
sigref = np.std(y_te_la)
avgref = np.mean(y_te_la)

sigpre = np.std(yhat_tr)
avgpre = np.mean(yhat_tr)

corr = np.sum((y_te_la - avgref)*(yhat_tr-avgpre))/sigref/sigpre/float(len(y_te_la))
print(corr)

#예측 효율 
mse_target = np.sum((y_te_la-yhat_tr)**2)/len(y_te_la)
mse_ref = np.sum((y_te_la-avgref)**2)/len(yhat_tr)
SS = 1-mse_target/mse_ref
print(SS)
# Out:
# 2578/2578 [==============================] - 6s 2ms/step
# acc: 96.86%
# predict
# acc : 96.86%
# 0.9848116759648792
# 0.9697491956446574
